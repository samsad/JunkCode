# %% [markdown]
# <a href="https://colab.research.google.com/github/samsad/JunkCode/blob/master/webscrap_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

def write_one_episode(episode_url):
 # url = "https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/"
  f = open("TBBT.txt", "a+")
  
  episode_heading = episode_url.split('/')
  f.write("\n------------------------------------------------")
  f.write("\n"+episode_heading[3])
  f.write("\n------------------------------------------------")
  
  episode_result = get(episode_url)
  episode_src = episode_result.content
  episode_soup = BeautifulSoup(episode_src, 'lxml')

  episode_link = episode_soup.find('div', { "class" : "entrytext"})
  rows  = episode_link.find_all('p')
  for x in rows:
   #print(x.get_text())
   f.write("\n"+x.get_text())
   
  f.write("\n\n------------END----------------\n\n")
  f.close()
  print(episode_heading[3]+"..... Done")

result = get("https://bigbangtrans.wordpress.com/")

src = result.content
soup = BeautifulSoup(src, 'lxml')

links = soup.find_all('a')
print("Started scraping")
for link in links:
  if "Series" in link.text:
    #print(link.attrs['href'])
    write_one_episode(link.attrs['href'])
    
print("Finished scraping")
# Out:
# Started scraping
# series-1-episode-1-pilot-episode..... Done
# series-1-episode-2-the-big-bran-hypothesis..... Done
# series-1-episode-3-the-fuzzy-boots-corollary..... Done
# series-1-episode-4-the-luminous-fish-effect..... Done
# series-1-episode-5-the-hamburger-postulate..... Done
# series-1-episode-6-the-middle-earth-paradigm..... Done
# series-1-episode-7-the-dumpling-paradox..... Done
# series-1-episode-8-the-grasshopper-experiment..... Done
# series-1-episode-9-the-cooper-hofstadter-polarization..... Done
# series-1-episode-10-the-loobenfeld-decay..... Done
# series-1-episode-11-the-pancake-batter-anomaly..... Done
# series-1-episode-12-the-jerusalem-duality..... Done
# series-1-episode-13-the-bat-jar-conjecture..... Done
# series-1-episode-14-the-nerdvana-annihilation..... Done
# series-1-episode-15-the-porkchop-indeterminacy..... Done
# series-1-episode-16-the-peanut-reaction..... Done
# series-1-episode-17-the-tangerine-factor..... Done
# ...
